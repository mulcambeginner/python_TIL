# %% [markdown]
# - PiLLOW 설치: jupyter=> !pip install Pillow, 프롬프트: conda install Pillow / pip install Pillow
# - import를 이용한 모듈 연결
# - 필요한 메소드(함수/명령어)를 이용해 작업수행

# %%
from PIL import Image
import pandas as pd

fileName=["pic1", "pic2", "pic3"]
prnData=[]   # 리스트 자료형 변수 생성

for fn in fileName:
    tmp=Image.open('./picture/'+fn+'.jpg')   # 그림 파일 열기
    fName=fn+'.jpg'    # 파일명 생성
    fm=tmp.format      # 파일 형식
    fw=tmp.width       # 그림 너비
    fh=tmp.height      # 그림 높이
    prnData.append([fName, fm, fw, fh])   # prnData 리스트 변수에 데이터 추가
    
    tmpRes=tmp.resize((300, 300))  # 이미지 사이즈 변경
    tmpRes.save('./data/'+fn+"_300.jpg")    

print("===== End =====")
print(prnData)

df=pd.DataFrame(prnData, columns=["파일명", "형식", "너비", "높이"])
df.to_csv('./파일정보.csv', encoding="cp949")
display(df)
print(df)
# Out:
# ===== End =====
# [['pic1.jpg', 'PNG', 512, 271], ['pic2.jpg', 'JPEG', 630, 338], ['pic3.jpg', 'JPEG', 275, 183]]
#         파일명    형식   너비   높이
# 0  pic1.jpg   PNG  512  271
# 1  pic2.jpg  JPEG  630  338
# 2  pic3.jpg  JPEG  275  183
#         파일명    형식   너비   높이
# 0  pic1.jpg   PNG  512  271
# 1  pic2.jpg  JPEG  630  338
# 2  pic3.jpg  JPEG  275  183

# %%
# !pip install pandas

# %% [markdown]
# ### [미션]
# - picture 폴더의 파일명 전체 가져오기
# - 그림파일만 체크해서 읽어와 진행
# - 각 파일별 파일명, 사이즈 저장하기(각 파일별 속성 확인: filename, format, width, height)
# - 각 파일별 사이즈 300 * 300 변경 후 data 폴더에 저장하기
# - 저장 파일명: 파일명_300.jpg

# %%
from PIL import Image
import pandas as pd
import os

fileDir="./picture/"
fileName=os.listdir(fileDir)

prnData=[]

for fn in fileName:
    if fn.split(".")[-1] == "jpg":
        tmp=Image.open(fileDir+fn)
        fm=tmp.format
        fw=tmp.width
        fh=tmp.height
        prnData.append([fn, fm, fw, fh])  
        # prnData.append({"파일명":fn, "형식":fm, "너비":fw, "높이":fh})
        tmpRes=tmp.resize((300,300))
        tmpRes.save('./data/'+fn.split(".")[0]+"_300."+fn.split(".")[-1])

df=pd.DataFrame(prnData, columns=["파일명", "형식", "너비", "높이"])
display(df)
print("==== 작업 완료 ====")
# Out:
#           파일명    형식   너비   높이
# 0    img1.jpg  JPEG  377  400
# 1   img10.jpg  JPEG  599  400
# 2   img11.jpg  JPEG  411  400
# 3   img12.jpg  JPEG  356  400
# 4   img13.jpg  JPEG  623  400
# 5   img14.jpg  JPEG  533  400
# 6   img15.jpg  JPEG  511  400
# 7   img16.jpg  JPEG  333  400
# 8   img17.jpg  JPEG  533  400
# 9   img18.jpg  JPEG  603  400
# 10  img19.jpg  JPEG  600  400
# 11   img2.jpg  JPEG  433  400
# 12  img20.jpg  JPEG  534  400
# 13  img21.jpg  JPEG  519  400
# 14  img22.jpg  JPEG  300  400
# 15  img23.jpg  JPEG  534  400
# 16  img24.jpg  JPEG  522  400
# 17  img25.jpg  JPEG  534  400
# 18  img26.jpg  JPEG  500  400
# 19  img27.jpg  JPEG  640  400
# 20  img28.jpg  JPEG  533  400
# 21  img29.jpg  JPEG  641  400
# 22   img3.jpg  JPEG  564  400
# 23  img30.jpg  JPEG  300  400
# 24   img4.jpg  JPEG  533  400
# 25   img5.jpg  JPEG  537  400
# 26   img6.jpg  JPEG  533  400
# 27   img7.jpg  JPEG  510  400
# 28   img8.jpg  JPEG  554  400
# 29   img9.jpg  JPEG  533  400
# 30   pic1.jpg   PNG  512  271
# 31   pic2.jpg  JPEG  630  338
# 32   pic3.jpg  JPEG  275  183
# ==== 작업 완료 ====
